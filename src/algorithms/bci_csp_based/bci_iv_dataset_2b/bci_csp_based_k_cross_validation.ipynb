# %%
from src.data_preparation.data_preparation import read_eeg_file
from scipy import signal
from src.algorithms.csp.CSP import CSP
import pywt
from scipy import stats
from sklearn.model_selection import KFold
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
import numpy as np

# %% [markdown]
# Declaration of important values used during the pipeline

# %%
TIME_LENGTH = 750
TIME_WINDOW = 500
EPOCH_SIZE = None
DATA_FOLDER = "data/bci-csp-based/bci-iv-dataset-2b"
CSP_COMPONENTS = 2
FS = 250
WAVELET = "coif1"
K_FOLD = 10

# %% [markdown]
# Create the subjects object and a dictionary to store the accuracies

# %%
subjects = range(1, 10)
subjects_set = set(subjects)
accuracies = {
    "GNB": np.zeros((len(subjects), K_FOLD)),
    "SVM": np.zeros((len(subjects), K_FOLD)),
    "LDA": np.zeros((len(subjects), K_FOLD))
}

# %% [markdown]
# Iterate on the subjects applying the algorithm, validating the results using the technique 10-fold cross-validation

# %%
for subject in subjects:
    print("========= Subject: ", subject)

    # Load data
    print("Loading data ...")
    left_data_file = f"{DATA_FOLDER}/left-hand-subject-{subject}.csv"
    right_data_file = f"{DATA_FOLDER}/right-hand-subject-{subject}.csv"
    data = read_eeg_file(left_data_file, right_data_file, TIME_LENGTH, TIME_WINDOW, EPOCH_SIZE)

    # Pre-processing
    print("Pre-processing ...")
    print("Applying 5º order Butterworth bandpass filter (7-30 Hz)")
    b, a = signal.butter(5, [7, 30], btype="bandpass", fs=FS)

    data.left_data = signal.filtfilt(b, a, data.left_data, axis=1)
    data.right_data = signal.filtfilt(b, a, data.right_data, axis=1)

    print("Spatial-filtering ...")
    data.X = np.concatenate((data.left_data, data.right_data))

    csp = CSP(average_trial_covariance=True, n_components=CSP_COMPONENTS)
    csp.fit(data.left_data, data.right_data)
    data.Z = np.array([csp.project(x) for x in data.X])

    # Feature extraction
    print("Extracting features ...")
    data.F = np.zeros((data.X.shape[0], 2, CSP_COMPONENTS))
    for n_epoch in range(0, data.X.shape[0]):
        epoch = data.Z[n_epoch]

        # Calculate the wavelet features
        for n_feature in range(0, data.F.shape[2]):
            alpha_band, beta_band = pywt.dwt(epoch[:, n_feature], WAVELET)
            data.F[n_epoch, 0, n_feature] = np.sum(beta_band ** 2)

        # Calculate the frequency-domain features
        psd_window_size = 100
        psd_window_overlap = psd_window_size//2
        beta_freqs = range(13, 31)
        for n_feature in range(0, data.F.shape[2]):
            freq, psd = signal.welch(epoch[:, n_feature], fs=FS, window="hanning",
                                     nperseg=psd_window_size, noverlap=psd_window_overlap)
            data.F[n_epoch, 1, n_feature] = np.sum(psd[beta_freqs] ** 2)

    len_features = data.F.shape[1] * data.F.shape[2]
    data.F = np.reshape(data.F, newshape=(data.F.shape[0], len_features))

    # Feature normalization
    data.F = stats.zscore(data.F, axis=0)

    # Classification
    print("Classifying features ...")
    subject_index = subject - 1

    cv = KFold(n_splits=K_FOLD, shuffle=True)
    for (k, (train_index, test_index)) in enumerate(cv.split(data.F)):
        X_train, X_test = data.F[train_index], data.F[test_index]
        y_train, y_test = data.labels[train_index], data.labels[test_index]

        # GNB classifier
        gnb = GaussianNB()
        gnb.fit(X_train, y_train)
        gnb_predictions = gnb.predict(X_test)
        gnb_accuracy = accuracy_score(y_test, gnb_predictions)
        print(f"GNB accuracy: {gnb_accuracy:.4f}")
        accuracies["GNB"][subject_index][k] = gnb_accuracy

        # SVM classifier
        svm = SVC(C=.8, gamma="scale", kernel="rbf")
        svm.fit(X_train, y_train)
        svm_predictions = svm.predict(X_test)
        svm_accuracy = accuracy_score(y_test, svm_predictions)
        print(f"SVM accuracy: {svm_accuracy:.4f}")
        accuracies["SVM"][subject_index][k] = svm_accuracy

        # LDA classifier
        lda = LinearDiscriminantAnalysis()
        lda.fit(X_train, y_train)
        lda_predictions = lda.predict(X_test)
        lda_accuracy = accuracy_score(y_test, lda_predictions)
        print(f"LDA accuracy: {lda_accuracy:.4f}")
        accuracies["LDA"][subject_index][k] = lda_accuracy

    print()
# Out:
# ========= Subject:  1
# Loading data ...
# Pre-processing ...
# Applying 5º order Butterworth bandpass filter (7-30 Hz)
# Spatial-filtering ...
# Extracting features ...
# Classifying features ...
# GNB accuracy: 0.5893
# SVM accuracy: 0.7500
# LDA accuracy: 0.7143
# GNB accuracy: 0.5536
# SVM accuracy: 0.6429
# LDA accuracy: 0.6607
# GNB accuracy: 0.6545
# SVM accuracy: 0.6182
# LDA accuracy: 0.7455
# GNB accuracy: 0.6364
# SVM accuracy: 0.6727
# LDA accuracy: 0.6727
# GNB accuracy: 0.6000
# SVM accuracy: 0.7273
# LDA accuracy: 0.7091
# GNB accuracy: 0.6182
# SVM accuracy: 0.6909
# LDA accuracy: 0.6727
# GNB accuracy: 0.5818
# SVM accuracy: 0.6000
# LDA accuracy: 0.6182
# GNB accuracy: 0.5818
# SVM accuracy: 0.6364
# LDA accuracy: 0.6182
# GNB accuracy: 0.6182
# SVM accuracy: 0.6909
# LDA accuracy: 0.7273
# GNB accuracy: 0.5636
# SVM accuracy: 0.7273
# LDA accuracy: 0.6909
#
# ========= Subject:  2
# Loading data ...
# Pre-processing ...
# Applying 5º order Butterworth bandpass filter (7-30 Hz)
# Spatial-filtering ...
# Extracting features ...
# Classifying features ...
# GNB accuracy: 0.3793
# SVM accuracy: 0.5862
# LDA accuracy: 0.5517
# GNB accuracy: 0.6034
# SVM accuracy: 0.5172
# LDA accuracy: 0.5690
# GNB accuracy: 0.5517
# SVM accuracy: 0.5172
# LDA accuracy: 0.5517
# GNB accuracy: 0.5517
# SVM accuracy: 0.5690
# LDA accuracy: 0.5862
# GNB accuracy: 0.4386
# SVM accuracy: 0.4912
# LDA accuracy: 0.4737
# GNB accuracy: 0.5965
# SVM accuracy: 0.6667
# LDA accuracy: 0.7193
# GNB accuracy: 0.6316
# SVM accuracy: 0.6316
# LDA accuracy: 0.6842
# GNB accuracy: 0.7368
# SVM accuracy: 0.5439
# LDA accuracy: 0.5789
# GNB accuracy: 0.4912
# SVM accuracy: 0.6842
# LDA accuracy: 0.5614
# GNB accuracy: 0.4561
# SVM accuracy: 0.6140
# LDA accuracy: 0.6316
#
# ========= Subject:  3
# Loading data ...
# Pre-processing ...
# Applying 5º order Butterworth bandpass filter (7-30 Hz)
# Spatial-filtering ...
# Extracting features ...
# Classifying features ...
# GNB accuracy: 0.5283
# SVM accuracy: 0.4717
# LDA accuracy: 0.6038
# GNB accuracy: 0.4906
# SVM accuracy: 0.5283
# LDA accuracy: 0.4906
# GNB accuracy: 0.5094
# SVM accuracy: 0.5472
# LDA accuracy: 0.4906
# GNB accuracy: 0.5660
# SVM accuracy: 0.4906
# LDA accuracy: 0.5660
# GNB accuracy: 0.6038
# SVM accuracy: 0.5660
# LDA accuracy: 0.5660
# GNB accuracy: 0.4717
# SVM accuracy: 0.5283
# LDA accuracy: 0.5472
# GNB accuracy: 0.5962
# SVM accuracy: 0.5000
# LDA accuracy: 0.4808
# GNB accuracy: 0.5192
# SVM accuracy: 0.5577
# LDA accuracy: 0.5577
# GNB accuracy: 0.4615
# SVM accuracy: 0.5577
# LDA accuracy: 0.5385
# GNB accuracy: 0.4615
# SVM accuracy: 0.5385
# LDA accuracy: 0.6346
#
# ========= Subject:  4
# Loading data ...
# Pre-processing ...
# Applying 5º order Butterworth bandpass filter (7-30 Hz)
# Spatial-filtering ...
# Extracting features ...
# Classifying features ...
# GNB accuracy: 0.8592
# SVM accuracy: 0.8873
# LDA accuracy: 0.8873
# GNB accuracy: 0.8028
# SVM accuracy: 0.8873
# LDA accuracy: 0.8592
# GNB accuracy: 0.8451
# SVM accuracy: 0.9014
# LDA accuracy: 0.9155
# GNB accuracy: 0.7746
# SVM accuracy: 0.8873
# LDA accuracy: 0.8451
# GNB accuracy: 0.7746
# SVM accuracy: 0.8873
# LDA accuracy: 0.8873
# GNB accuracy: 0.8028
# SVM accuracy: 0.8451
# LDA accuracy: 0.7887
# GNB accuracy: 0.8429
# SVM accuracy: 0.8286
# LDA accuracy: 0.8286
# GNB accuracy: 0.8571
# SVM accuracy: 0.9143
# LDA accuracy: 0.9143
# GNB accuracy: 0.7286
# SVM accuracy: 0.8429
# LDA accuracy: 0.8857
# GNB accuracy: 0.8571
# SVM accuracy: 0.9143
# LDA accuracy: 0.8571
#
# ========= Subject:  5
# Loading data ...
# Pre-processing ...
# Applying 5º order Butterworth bandpass filter (7-30 Hz)
# Spatial-filtering ...
# Extracting features ...
# Classifying features ...
# GNB accuracy: 0.8636
# SVM accuracy: 0.8939
# LDA accuracy: 0.8788
# GNB accuracy: 0.8030
# SVM accuracy: 0.9394
# LDA accuracy: 0.8636
# GNB accuracy: 0.8788
# SVM accuracy: 0.8636
# LDA accuracy: 0.8636
# GNB accuracy: 0.8485
# SVM accuracy: 0.8333
# LDA accuracy: 0.8636
# GNB accuracy: 0.7727
# SVM accuracy: 0.7727
# LDA accuracy: 0.7879
# GNB accuracy: 0.7846
# SVM accuracy: 0.8154
# LDA accuracy: 0.8615
# GNB accuracy: 0.8923
# SVM accuracy: 0.8769
# LDA accuracy: 0.9077
# GNB accuracy: 0.8000
# SVM accuracy: 0.8308
# LDA accuracy: 0.8154
# GNB accuracy: 0.8769
# SVM accuracy: 0.8769
# LDA accuracy: 0.8769
# GNB accuracy: 0.7846
# SVM accuracy: 0.8769
# LDA accuracy: 0.8308
#
# ========= Subject:  6
# Loading data ...
# Pre-processing ...
# Applying 5º order Butterworth bandpass filter (7-30 Hz)
# Spatial-filtering ...
# Extracting features ...
# Classifying features ...
# GNB accuracy: 0.6182
# SVM accuracy: 0.7091
# LDA accuracy: 0.7455
# GNB accuracy: 0.6909
# SVM accuracy: 0.6545
# LDA accuracy: 0.6909
# GNB accuracy: 0.6545
# SVM accuracy: 0.7455
# LDA accuracy: 0.7455
# GNB accuracy: 0.7455
# SVM accuracy: 0.7455
# LDA accuracy: 0.7273
# GNB accuracy: 0.6364
# SVM accuracy: 0.7455
# LDA accuracy: 0.7273
# GNB accuracy: 0.6000
# SVM accuracy: 0.8182
# LDA accuracy: 0.8000
# GNB accuracy: 0.7222
# SVM accuracy: 0.7222
# LDA accuracy: 0.7778
# GNB accuracy: 0.7593
# SVM accuracy: 0.7778
# LDA accuracy: 0.7593
# GNB accuracy: 0.6296
# SVM accuracy: 0.6852
# LDA accuracy: 0.6852
# GNB accuracy: 0.4815
# SVM accuracy: 0.6852
# LDA accuracy: 0.6481
#
# ========= Subject:  7
# Loading data ...
# Pre-processing ...
# Applying 5º order Butterworth bandpass filter (7-30 Hz)
# Spatial-filtering ...
# Extracting features ...
# Classifying features ...
# GNB accuracy: 0.7119
# SVM accuracy: 0.6610
# LDA accuracy: 0.6102
# GNB accuracy: 0.5254
# SVM accuracy: 0.5932
# LDA accuracy: 0.5593
# GNB accuracy: 0.6610
# SVM accuracy: 0.6610
# LDA accuracy: 0.6780
# GNB accuracy: 0.5932
# SVM accuracy: 0.7627
# LDA accuracy: 0.7288
# GNB accuracy: 0.6610
# SVM accuracy: 0.6780
# LDA accuracy: 0.6780
# GNB accuracy: 0.5085
# SVM accuracy: 0.6780
# LDA accuracy: 0.6780
# GNB accuracy: 0.5932
# SVM accuracy: 0.7288
# LDA accuracy: 0.7119
# GNB accuracy: 0.6949
# SVM accuracy: 0.7627
# LDA accuracy: 0.6949
# GNB accuracy: 0.6207
# SVM accuracy: 0.7241
# LDA accuracy: 0.7414
# GNB accuracy: 0.6034
# SVM accuracy: 0.6897
# LDA accuracy: 0.5690
#
# ========= Subject:  8
# Loading data ...
# Pre-processing ...
# Applying 5º order Butterworth bandpass filter (7-30 Hz)
# Spatial-filtering ...
# Extracting features ...
# Classifying features ...
# GNB accuracy: 0.7500
# SVM accuracy: 0.7679
# LDA accuracy: 0.8036
# GNB accuracy: 0.6250
# SVM accuracy: 0.6429
# LDA accuracy: 0.6250
# GNB accuracy: 0.5536
# SVM accuracy: 0.6429
# LDA accuracy: 0.6786
# GNB accuracy: 0.8214
# SVM accuracy: 0.7679
# LDA accuracy: 0.7679
# GNB accuracy: 0.6429
# SVM accuracy: 0.6786
# LDA accuracy: 0.5893
# GNB accuracy: 0.7500
# SVM accuracy: 0.7500
# LDA accuracy: 0.7143
# GNB accuracy: 0.6607
# SVM accuracy: 0.7857
# LDA accuracy: 0.7500
# GNB accuracy: 0.7500
# SVM accuracy: 0.7500
# LDA accuracy: 0.7500
# GNB accuracy: 0.8000
# SVM accuracy: 0.7818
# LDA accuracy: 0.7636
# GNB accuracy: 0.7091
# SVM accuracy: 0.6727
# LDA accuracy: 0.6545
#
# ========= Subject:  9
# Loading data ...
# Pre-processing ...
# Applying 5º order Butterworth bandpass filter (7-30 Hz)
# Spatial-filtering ...
# Extracting features ...
# Classifying features ...
# GNB accuracy: 0.7018
# SVM accuracy: 0.8596
# LDA accuracy: 0.7719
# GNB accuracy: 0.7544
# SVM accuracy: 0.7368
# LDA accuracy: 0.7544
# GNB accuracy: 0.6429
# SVM accuracy: 0.8036
# LDA accuracy: 0.8036
# GNB accuracy: 0.5179
# SVM accuracy: 0.7857
# LDA accuracy: 0.8036
# GNB accuracy: 0.5357
# SVM accuracy: 0.8036
# LDA accuracy: 0.7679
# GNB accuracy: 0.5536
# SVM accuracy: 0.7679
# LDA accuracy: 0.7500
# GNB accuracy: 0.4107
# SVM accuracy: 0.8036
# LDA accuracy: 0.7679
# GNB accuracy: 0.7143
# SVM accuracy: 0.8214
# LDA accuracy: 0.8571
# GNB accuracy: 0.4821
# SVM accuracy: 0.7143
# LDA accuracy: 0.7857
# GNB accuracy: 0.6964
# SVM accuracy: 0.7321
# LDA accuracy: 0.6607

# %% [markdown]
# Print the results obtained by the 10-fold cross-validation from each classification algorithm

# %%
for classifier in accuracies:
    print(classifier)
    for subject, cv_accuracies in enumerate(accuracies[classifier]):
        acc_mean = np.mean(cv_accuracies)
        acc_std = np.std(cv_accuracies)
        print(f"\tSubject {subject+1} average accuracy: {acc_mean:.4f} +/- {acc_std:.4f}")
    average_acc_mean = np.mean(accuracies[classifier])
    average_acc_std = np.std(accuracies[classifier])
    print(f"\tAverage accuracy: {average_acc_mean:.4f} +/- {average_acc_std:.4f}")
# Out:
# GNB
# 	Subject 1 average accuracy: 0.5997 +/- 0.0304
# 	Subject 2 average accuracy: 0.5437 +/- 0.1000
# 	Subject 3 average accuracy: 0.5208 +/- 0.0501
# 	Subject 4 average accuracy: 0.8145 +/- 0.0427
# 	Subject 5 average accuracy: 0.8305 +/- 0.0435
# 	Subject 6 average accuracy: 0.6538 +/- 0.0777
# 	Subject 7 average accuracy: 0.6173 +/- 0.0636
# 	Subject 8 average accuracy: 0.7063 +/- 0.0799
# 	Subject 9 average accuracy: 0.6010 +/- 0.1101
# 	Average accuracy: 0.6542 +/- 0.1258
# SVM
# 	Subject 1 average accuracy: 0.6756 +/- 0.0479
# 	Subject 2 average accuracy: 0.5821 +/- 0.0627
# 	Subject 3 average accuracy: 0.5286 +/- 0.0301
# 	Subject 4 average accuracy: 0.8796 +/- 0.0288
# 	Subject 5 average accuracy: 0.8580 +/- 0.0441
# 	Subject 6 average accuracy: 0.7289 +/- 0.0458
# 	Subject 7 average accuracy: 0.6939 +/- 0.0494
# 	Subject 8 average accuracy: 0.7240 +/- 0.0550
# 	Subject 9 average accuracy: 0.7829 +/- 0.0428
# 	Average accuracy: 0.7171 +/- 0.1184
# LDA
# 	Subject 1 average accuracy: 0.6830 +/- 0.0409
# 	Subject 2 average accuracy: 0.5908 +/- 0.0672
# 	Subject 3 average accuracy: 0.5476 +/- 0.0475
# 	Subject 4 average accuracy: 0.8669 +/- 0.0374
# 	Subject 5 average accuracy: 0.8550 +/- 0.0328
# 	Subject 6 average accuracy: 0.7307 +/- 0.0433
# 	Subject 7 average accuracy: 0.6649 +/- 0.0607
# 	Subject 8 average accuracy: 0.7097 +/- 0.0664
# 	Subject 9 average accuracy: 0.7723 +/- 0.0476
# 	Average accuracy: 0.7134 +/- 0.1137
